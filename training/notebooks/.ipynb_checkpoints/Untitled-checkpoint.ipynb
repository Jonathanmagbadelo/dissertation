# %% [markdown]
# # Data Analysis

# %%
import pandas as pd 
import os
os.chdir('../')
print(os.getcwd())
# Out:
# /home/akin/PycharmProjects/training
# /home/akin/.local/share/virtualenvs/training-tXXqW76R/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)

# %% [markdown]
# ## Load Lyric Corpus

# %%
import csv
from nltk.corpus import stopwords

stop = stopwords.words('english')
embeddings = []
id_to_covariate = {'0': 'Pop', '1':'Rock', '2': 'Hip Hop' }

with open("data/corpus.txt", "r") as csv_file:
        reader = csv.reader(csv_file, delimiter=' ')
        for embedding in reader:
            embeddings.append([embedding[0], embedding[1:]])
corpus = pd.DataFrame(embeddings, columns=['covariate', 'lyric'])
corpus['covariate'] = corpus['covariate'].map(id_to_covariate)
corpus['lyric'] = corpus['lyric'].apply(lambda x: [item for item in x if item not in stop])
corpus.head(10)
# Out:
# /home/akin/.local/share/virtualenvs/training-tXXqW76R/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /home/akin/.local/share/virtualenvs/training-tXXqW76R/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /home/akin/.local/share/virtualenvs/training-tXXqW76R/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
#   covariate                                              lyric
# 0       Pop  [daddy, daddy, poppy, poppy, need, dance, caus...
# 1       Pop  [point, need, everybody, dance, floor, like, y...
# 2       Pop  [crooks, tryna, steal, heart, never, really, l...
# 3       Pop  [blank, pages, diary, havent, touched, since, ...
# 4       Pop  [christmas, time, thing, want, tops, better, e...
# 5       Pop  [back, homeward, back, home, sleep, pretty, da...
# 6       Pop  [follow, river, head, time, take, river, baby,...
# 7       Pop  [taking, youve, given, thinkin, livin, fantasy...
# 8       Pop  [hard, time, sleeping, hours, landed, show, th...
# 9       Pop  [need, stop, playing, round, clowns, wangstas,...

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Average Number of Words per Lyrics per Genre

# %%
import seaborn as sns
plt.subplots(figsize=(10,10))
sns.set(font_scale = 2)
corpus['word_count'] = corpus['lyric'].str.len()
d = corpus['word_count'].groupby(corpus['covariate']).mean().to_frame()
d.reset_index(level=0, inplace=True)
n = sns.barplot(x="covariate",y="word_count", data=d)

# %% [markdown]
# ## Most Common Words per Genre

# %%
from itertools import chain
from collections import Counter
common_words_per_genre = []
for covariate in corpus['covariate'].unique():
    covariate_corpus = corpus[corpus['covariate'] == covariate]
    lyrics = chain.from_iterable(covariate_corpus['lyric'].to_list())
    covariate_word_count = Counter(lyrics)
    common_words_per_genre.append(covariate_word_count)

# %%
from matplotlib import pyplot as plt

for i, covariate_word_count in enumerate(common_words_per_genre):
    plt.subplots(figsize=(20,15))
    keys, values = zip(*covariate_word_count.most_common(12))
    data = {"word": keys, "count": values}
    common_words_df = pd.DataFrame.from_dict(data)
    common_words_plot = sns.barplot(x="word",y="count", data=common_words_df, ).set_title("Most Common Words in {}".format(id_to_covariate[str(i)]))
